# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
import warnings

# Suppress all warnings
warnings.filterwarnings("ignore")

# %%
matches = pd.read_csv("matches.csv", index_col = 0)
matches.head()
# Out:
#          date   time            comp        round  day venue result  gf  ga  \
# 1  2023-08-11  20:00  Premier League  Matchweek 1  Fri  Away      W   3   0
# 3  2023-08-19  20:00  Premier League  Matchweek 2  Sat  Home      W   1   0
# 4  2023-08-27  14:00  Premier League  Matchweek 3  Sun  Away      W   2   1
# 5  2023-09-02  15:00  Premier League  Matchweek 4  Sat  Home      W   5   1
# 6  2023-09-16  15:00  Premier League  Matchweek 5  Sat  Away      W   3   1
#
#         opponent  ...  match report  notes    sh   sot  dist   fk pk pkatt  \
# 1        Burnley  ...  Match Report    NaN  17.0   8.0  13.9  0.0  0     0
# 3  Newcastle Utd  ...  Match Report    NaN  14.0   4.0  17.9  0.0  0     0
# 4  Sheffield Utd  ...  Match Report    NaN  29.0   9.0  17.3  2.0  0     1
# 5         Fulham  ...  Match Report    NaN   6.0   4.0  14.8  0.0  1     1
# 6       West Ham  ...  Match Report    NaN  29.0  13.0  16.4  1.0  0     0
#
#   season             team
# 1   2023  Manchester City
# ...

# %%
matches["team"].value_counts()
# Out:
# team
# Manchester City             76
# Crystal Palace              76
# Nottingham Forest           76
# Brentford                   76
# Everton                     76
# Wolverhampton Wanderers     76
# Fulham                      76
# Arsenal                     76
# Brighton and Hove Albion    76
# Bournemouth                 76
# West Ham United             76
# Manchester United           76
# Newcastle United            76
# Chelsea                     76
# Tottenham Hotspur           76
# Aston Villa                 76
# Liverpool                   76
# Luton Town                  38
# Burnley                     38
# Sheffield United            38
# Leicester City              38
# Leeds United                38
# Southampton                 38
# Name: count, dtype: int64

# %%
matches[matches["team"] == "Manchester City"]
# Out:
#           date   time            comp         round  day venue result  gf  ga  \
# 1   2023-08-11  20:00  Premier League   Matchweek 1  Fri  Away      W   3   0
# 3   2023-08-19  20:00  Premier League   Matchweek 2  Sat  Home      W   1   0
# 4   2023-08-27  14:00  Premier League   Matchweek 3  Sun  Away      W   2   1
# 5   2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      W   5   1
# 6   2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away      W   3   1
# ..         ...    ...             ...           ...  ...   ...    ...  ..  ..
# 52  2023-05-06  15:00  Premier League  Matchweek 35  Sat  Home      W   2   1
# 54  2023-05-14  14:00  Premier League  Matchweek 36  Sun  Away      W   3   0
# 56  2023-05-21  16:00  Premier League  Matchweek 37  Sun  Home      W   1   0
# 57  2023-05-24  20:00  Premier League  Matchweek 32  Wed  Away      D   1   1
# 58  2023-05-28  16:30  Premier League  Matchweek 38  Sun  Away      L   0   1
#
# ...

# %%
matches["round"].value_counts()
# Out:
# round
# Matchweek 1     40
# Matchweek 30    40
# Matchweek 23    40
# Matchweek 24    40
# Matchweek 25    40
# Matchweek 18    40
# Matchweek 26    40
# Matchweek 27    40
# Matchweek 28    40
# Matchweek 31    40
# Matchweek 2     40
# Matchweek 32    40
# Matchweek 33    40
# Matchweek 29    40
# Matchweek 35    40
# Matchweek 36    40
# Matchweek 37    40
# Matchweek 34    40
# Matchweek 22    40
# Matchweek 21    40
# Matchweek 20    40
# Matchweek 19    40
# Matchweek 3     40
# Matchweek 4     40
# Matchweek 5     40
# Matchweek 6     40
# Matchweek 7     40
# Matchweek 8     40
# Matchweek 9     40
# Matchweek 10    40
# Matchweek 11    40
# Matchweek 12    40
# Matchweek 13    40
# Matchweek 14    40
# Matchweek 15    40
# Matchweek 16    40
# Matchweek 17    40
# Matchweek 38    40
# Name: count, dtype: int64

# %%
matches.dtypes
# Out:
# date              object
# time              object
# comp              object
# round             object
# day               object
# venue             object
# result            object
# gf                 int64
# ga                 int64
# opponent          object
# xg               float64
# xga              float64
# poss             float64
# attendance       float64
# captain           object
# formation         object
# opp formation     object
# referee           object
# match report      object
# notes            float64
# sh               float64
# sot              float64
# dist             float64
# fk               float64
# pk                 int64
# pkatt              int64
# season             int64
# team              object
# dtype: object

# %%
matches["date"] = pd.to_datetime(matches["date"])
matches.dtypes
# Out:
# date             datetime64[ns]
# time                     object
# comp                     object
# round                    object
# day                      object
# venue                    object
# result                   object
# gf                        int64
# ga                        int64
# opponent                 object
# xg                      float64
# xga                     float64
# poss                    float64
# attendance              float64
# captain                  object
# formation                object
# opp formation            object
# referee                  object
# match report             object
# notes                   float64
# sh                      float64
# sot                     float64
# dist                    float64
# fk                      float64
# pk                        int64
# pkatt                     int64
# season                    int64
# team                     object
# dtype: object

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes
matches["opp_code"] = matches["opponent"].astype("category").cat.codes
matches["hour"] = matches["time"].str.replace(":.+", "", regex = True).astype("int")
matches["day_code"] = matches["date"].dt.dayofweek
matches["target"] = (matches["result"] == "W").astype("int")
matches
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 1  2023-08-11  20:00  Premier League   Matchweek 1  Fri  Away      W   3   0
# 3  2023-08-19  20:00  Premier League   Matchweek 2  Sat  Home      W   1   0
# 4  2023-08-27  14:00  Premier League   Matchweek 3  Sun  Away      W   2   1
# 5  2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      W   5   1
# 6  2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away      W   3   1
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 42 2023-04-30  14:00  Premier League  Matchweek 34  Sun  Away      L   1   3
# 43 2023-05-08  20:00  Premier League  Matchweek 35  Mon  Away      L   3   4
# 44 2023-05-13  15:00  Premier League  Matchweek 36  Sat  Home      L   0   2
# 45 2023-05-21  14:00  Premier League  Matchweek 37  Sun  Away      L   1   3
# 46 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Home      D   4   4
#
# ...

# %%
rf = RandomForestClassifier(n_estimators = 50, min_samples_split = 10, random_state = 1)

train = matches[matches["date"] < '2024-01-01']
test = matches[matches["date"] > '2024-01-01']
predictors = ["venue_code", "opp_code", "hour", "day_code"]

rf.fit(train[predictors], train["target"])
RandomForestClassifier(min_samples_split = 10, n_estimators = 50, random_state = 1)
preds = rf.predict(test[predictors])

acc = accuracy_score(test["target"], preds)
acc
# Out:
# 0.6229508196721312

# %%
combined = pd.DataFrame(dict(actual = test["target"], prediction = preds))
pd.crosstab(index = combined["actual"], columns = combined["prediction"])
# Out:
# prediction    0   1
# actual
# 0           168  61
# 1            77  60

# %%
precision_score(test["target"], preds, average="weighted")
# Out:
# 0.6146515183773008

# %%
grouped_matches = matches.groupby("team")
group = grouped_matches.get_group("Manchester City")
group
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 1  2023-08-11  20:00  Premier League   Matchweek 1  Fri  Away      W   3   0
# 3  2023-08-19  20:00  Premier League   Matchweek 2  Sat  Home      W   1   0
# 4  2023-08-27  14:00  Premier League   Matchweek 3  Sun  Away      W   2   1
# 5  2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      W   5   1
# 6  2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away      W   3   1
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 52 2023-05-06  15:00  Premier League  Matchweek 35  Sat  Home      W   2   1
# 54 2023-05-14  14:00  Premier League  Matchweek 36  Sun  Away      W   3   0
# 56 2023-05-21  16:00  Premier League  Matchweek 37  Sun  Home      W   1   0
# 57 2023-05-24  20:00  Premier League  Matchweek 32  Wed  Away      D   1   1
# 58 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Away      L   0   1
#
# ...

# %%
def rolling_averages(group, cols, new_cols, window=3):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(window, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

rolling_averages(group, cols, new_cols)
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 4  2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home      W   4   2
# 5  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W   6   0
# 6  2022-09-03  17:30  Premier League   Matchweek 6  Sat  Away      D   1   1
# 9  2022-09-17  12:30  Premier League   Matchweek 8  Sat  Away      W   3   0
# 10 2022-10-02  14:00  Premier League   Matchweek 9  Sun  Home      W   6   3
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 51 2024-04-28  16:30  Premier League  Matchweek 35  Sun  Away      W   2   0
# 52 2024-05-04  17:30  Premier League  Matchweek 36  Sat  Home      W   5   1
# 53 2024-05-11  12:30  Premier League  Matchweek 37  Sat  Away      W   4   0
# 54 2024-05-14  20:00  Premier League  Matchweek 34  Tue  Away      W   2   0
# 55 2024-05-19  16:00  Premier League  Matchweek 38  Sun  Home      W   3   1
#
# ...

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
matches_rolling = matches_rolling.droplevel("team")

# %%
matches_rolling
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 3  2022-08-27  17:30  Premier League   Matchweek 4  Sat  Home      W   2   1
# 4  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W   2   1
# 5  2022-09-04  16:30  Premier League   Matchweek 6  Sun  Away      L   1   3
# 7  2022-09-18  12:00  Premier League   Matchweek 8  Sun  Away      W   3   0
# 8  2022-10-01  12:30  Premier League   Matchweek 9  Sat  Home      W   3   1
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 40 2024-04-24  19:45  Premier League  Matchweek 29  Wed  Home      L   0   1
# 41 2024-04-27  15:00  Premier League  Matchweek 35  Sat  Home      W   2   1
# 42 2024-05-04  17:30  Premier League  Matchweek 36  Sat  Away      L   1   5
# 43 2024-05-11  15:00  Premier League  Matchweek 37  Sat  Home      L   1   3
# 44 2024-05-19  16:00  Premier League  Matchweek 38  Sun  Away      L   0   2
#
# ...

# %%
def add_opponent_rolling(data, cols, new_cols):
    opponent_stats = data[["team", "date"] + new_cols].rename(columns = {col: f"opp_{col}" for col in new_cols})
    merged = data.merge(opponent_stats, left_on=["opponent", "date"], right_on=["team", "date"], how="left", suffixes=("", "_y"))
    merged.drop(columns=[col for col in merged.columns if "_y" in col])
    return merged

matches_rolling = add_opponent_rolling(matches_rolling, cols, new_cols)

rolling_predictors = new_cols + [f"opp_{col}" for col in new_cols]
predictors = ["venue_code", "opp_code", "hour", "day_code"] + rolling_predictors

# %%
matches_rolling = add_opponent_rolling(matches_rolling, cols, new_cols)

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2024-01-01']
    test = data[data["date"] > '2024-01-01']

    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual = test["target"], prediction = preds), index = test.index)

    precision = precision_score(test["target"], preds, average = "weighted")
    return combined, precision

combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.6542499684299949

# %%
matches_rolling
# Out:
#            date   time            comp         round  day venue result  gf  \
# 0    2022-08-27  17:30  Premier League   Matchweek 4  Sat  Home      W   2
# 1    2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W   2
# 2    2022-09-04  16:30  Premier League   Matchweek 6  Sun  Away      L   1
# 3    2022-09-18  12:00  Premier League   Matchweek 8  Sun  Away      W   3
# 4    2022-10-01  12:30  Premier League   Matchweek 9  Sat  Home      W   3
# ...         ...    ...             ...           ...  ...   ...    ...  ..
# 1446 2024-04-24  19:45  Premier League  Matchweek 29  Wed  Home      L   0
# 1447 2024-04-27  15:00  Premier League  Matchweek 35  Sat  Home      W   2
# 1448 2024-05-04  17:30  Premier League  Matchweek 36  Sat  Away      L   1
# 1449 2024-05-11  15:00  Premier League  Matchweek 37  Sat  Home      L   1
# 1450 2024-05-19  16:00  Premier League  Matchweek 38  Sun  Away      L   0
#
# ...

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)
combined
# Out:
#       actual  prediction       date                     team         opponent  \
# 55         1           0 2024-01-20                  Arsenal   Crystal Palace
# 56         1           1 2024-01-30                  Arsenal  Nott'ham Forest
# 57         1           0 2024-02-04                  Arsenal        Liverpool
# 58         1           1 2024-02-11                  Arsenal         West Ham
# 59         1           0 2024-02-17                  Arsenal          Burnley
# ...      ...         ...        ...                      ...              ...
# 1446       0           0 2024-04-24  Wolverhampton Wanderers      Bournemouth
# 1447       1           1 2024-04-27  Wolverhampton Wanderers       Luton Town
# 1448       0           0 2024-05-04  Wolverhampton Wanderers  Manchester City
# 1449       0           0 2024-05-11  Wolverhampton Wanderers   Crystal Palace
# 1450       0           0 2024-05-19  Wolverhampton Wanderers        Liverpool
#
#      result
# 55        W
# ...

# %%
precision
# Out:
# 0.6542499684299949

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton", "Manchester United": "Manchester Utd", "Newcastle United": "Newcastle Utd", "Tottenham Hotspur": "Tottenham", "West Ham United": "West Ham", "Wolverhampton Wanderers": "Wolves"} 
mapping = MissingDict(**map_values)
mapping["Wolverhampton Wanderers"]
# Out:
# 'Wolves'

# %%
combined["new_team"] = combined["team"].map(mapping)
merged = combined.merge(combined, left_on = ["date", "new_team"], right_on = ["date", "opponent"])

# %%
merged
# Out:
#      actual_x  prediction_x       date                   team_x  \
# 0           1             0 2024-01-20                  Arsenal
# 1           1             1 2024-01-30                  Arsenal
# 2           1             0 2024-02-04                  Arsenal
# 3           1             1 2024-02-11                  Arsenal
# 4           1             0 2024-02-17                  Arsenal
# ..        ...           ...        ...                      ...
# 325         0             0 2024-04-24  Wolverhampton Wanderers
# 326         1             1 2024-04-27  Wolverhampton Wanderers
# 327         0             0 2024-05-04  Wolverhampton Wanderers
# 328         0             0 2024-05-11  Wolverhampton Wanderers
# 329         0             0 2024-05-19  Wolverhampton Wanderers
#
#           opponent_x result_x new_team_x  actual_y  prediction_y  \
# 0     Crystal Palace        W    Arsenal         0             0
# ...

# %%
merged[(merged["prediction_x"] == 1) & (merged["prediction_y"] == 0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    67
# 0    48
# Name: count, dtype: int64

# %%
combined = combined.merge(
    matches_rolling[["date", "team", "opponent", "result"]],
    left_index=True,
    right_index=True,
    suffixes=("", "_extra")
)
combined.to_csv("predictions.csv", index=False)
