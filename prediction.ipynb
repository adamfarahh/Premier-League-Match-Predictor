# %%
import pandas as pd

# %%
matches = pd.read_csv("matches.csv", index_col = 0)
matches.head()
# Out:
#          date   time            comp        round  day venue result  gf  ga  \
# 1  2023-08-11  20:00  Premier League  Matchweek 1  Fri  Away      W   3   0
# 3  2023-08-19  20:00  Premier League  Matchweek 2  Sat  Home      W   1   0
# 4  2023-08-27  14:00  Premier League  Matchweek 3  Sun  Away      W   2   1
# 5  2023-09-02  15:00  Premier League  Matchweek 4  Sat  Home      W   5   1
# 6  2023-09-16  15:00  Premier League  Matchweek 5  Sat  Away      W   3   1
#
#         opponent  ...  match report  notes    sh   sot  dist   fk pk pkatt  \
# 1        Burnley  ...  Match Report    NaN  17.0   8.0  13.9  0.0  0     0
# 3  Newcastle Utd  ...  Match Report    NaN  14.0   4.0  17.9  0.0  0     0
# 4  Sheffield Utd  ...  Match Report    NaN  29.0   9.0  17.3  2.0  0     1
# 5         Fulham  ...  Match Report    NaN   6.0   4.0  14.8  0.0  1     1
# 6       West Ham  ...  Match Report    NaN  29.0  13.0  16.4  1.0  0     0
#
#   season             team
# 1   2023  Manchester City
# ...

# %%
matches["team"].value_counts()
# Out:
# team
# Manchester City             76
# Crystal Palace              76
# Nottingham Forest           76
# Brentford                   76
# Everton                     76
# Wolverhampton Wanderers     76
# Fulham                      76
# Arsenal                     76
# Brighton and Hove Albion    76
# Bournemouth                 76
# West Ham United             76
# Manchester United           76
# Newcastle United            76
# Chelsea                     76
# Tottenham Hotspur           76
# Aston Villa                 76
# Liverpool                   76
# Luton Town                  38
# Burnley                     38
# Sheffield United            38
# Leicester City              38
# Leeds United                38
# Southampton                 38
# Name: count, dtype: int64

# %%
matches[matches["team"] == "Manchester City"]
# Out:
#           date   time            comp         round  day venue result  gf  ga  \
# 1   2023-08-11  20:00  Premier League   Matchweek 1  Fri  Away      W   3   0
# 3   2023-08-19  20:00  Premier League   Matchweek 2  Sat  Home      W   1   0
# 4   2023-08-27  14:00  Premier League   Matchweek 3  Sun  Away      W   2   1
# 5   2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      W   5   1
# 6   2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away      W   3   1
# ..         ...    ...             ...           ...  ...   ...    ...  ..  ..
# 52  2023-05-06  15:00  Premier League  Matchweek 35  Sat  Home      W   2   1
# 54  2023-05-14  14:00  Premier League  Matchweek 36  Sun  Away      W   3   0
# 56  2023-05-21  16:00  Premier League  Matchweek 37  Sun  Home      W   1   0
# 57  2023-05-24  20:00  Premier League  Matchweek 32  Wed  Away      D   1   1
# 58  2023-05-28  16:30  Premier League  Matchweek 38  Sun  Away      L   0   1
#
# ...

# %%
matches["round"].value_counts()
# Out:
# round
# Matchweek 1     40
# Matchweek 30    40
# Matchweek 23    40
# Matchweek 24    40
# Matchweek 25    40
# Matchweek 18    40
# Matchweek 26    40
# Matchweek 27    40
# Matchweek 28    40
# Matchweek 31    40
# Matchweek 2     40
# Matchweek 32    40
# Matchweek 33    40
# Matchweek 29    40
# Matchweek 35    40
# Matchweek 36    40
# Matchweek 37    40
# Matchweek 34    40
# Matchweek 22    40
# Matchweek 21    40
# Matchweek 20    40
# Matchweek 19    40
# Matchweek 3     40
# Matchweek 4     40
# Matchweek 5     40
# Matchweek 6     40
# Matchweek 7     40
# Matchweek 8     40
# Matchweek 9     40
# Matchweek 10    40
# Matchweek 11    40
# Matchweek 12    40
# Matchweek 13    40
# Matchweek 14    40
# Matchweek 15    40
# Matchweek 16    40
# Matchweek 17    40
# Matchweek 38    40
# Name: count, dtype: int64

# %%
matches.dtypes
# Out:
# date              object
# time              object
# comp              object
# round             object
# day               object
# venue             object
# result            object
# gf                 int64
# ga                 int64
# opponent          object
# xg               float64
# xga              float64
# poss             float64
# attendance       float64
# captain           object
# formation         object
# opp formation     object
# referee           object
# match report      object
# notes            float64
# sh               float64
# sot              float64
# dist             float64
# fk               float64
# pk                 int64
# pkatt              int64
# season             int64
# team              object
# dtype: object

# %%
matches["date"] = pd.to_datetime(matches["date"])
matches
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 1  2023-08-11  20:00  Premier League   Matchweek 1  Fri  Away      W   3   0
# 3  2023-08-19  20:00  Premier League   Matchweek 2  Sat  Home      W   1   0
# 4  2023-08-27  14:00  Premier League   Matchweek 3  Sun  Away      W   2   1
# 5  2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      W   5   1
# 6  2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away      W   3   1
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 42 2023-04-30  14:00  Premier League  Matchweek 34  Sun  Away      L   1   3
# 43 2023-05-08  20:00  Premier League  Matchweek 35  Mon  Away      L   3   4
# 44 2023-05-13  15:00  Premier League  Matchweek 36  Sat  Home      L   0   2
# 45 2023-05-21  14:00  Premier League  Matchweek 37  Sun  Away      L   1   3
# 46 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Home      D   4   4
#
# ...
